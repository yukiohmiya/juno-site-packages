# %%
# %matplotlib inline

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1, 3, 5, 6])

# %%
x = np.random.normal(50, 10, 1000)
plt.hist(x)
# Out:
# (array([  3.,  28.,  76., 183., 243., 241., 142.,  61.,  19.,   4.]),
#  array([18.06405687, 24.58574017, 31.10742346, 37.62910676, 44.15079005,
#         50.67247335, 57.19415664, 63.71583994, 70.23752323, 76.75920653,
#         83.28088982]),
#  <a list of 10 Patch objects>)
