# %% [markdown]
# # Introduction to Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import japanize_matplotlib
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.arange(0, 2*np.pi, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
x = np.random.randn(30)
y = np.sin(x) + np.random.randn(30)
plt.plot(x, y, "o")
# "o"は小さい円(circle marker)

# %%
plt.plot(x, y, "ro")

# %% [markdown]
# ```
# ?plt.plot
# ```

# %%
plt.hist(np.random.randn(1000))
# Out:
# (array([  5.,  21.,  77., 201., 222., 246., 134.,  77.,  13.,   4.]),
#  array([-3.31125293, -2.63491328, -1.95857364, -1.28223399, -0.60589435,
#          0.0704453 ,  0.74678494,  1.42312459,  2.09946423,  2.77580388,
#          3.45214352]),
#  <a list of 10 Patch objects>)

# %%
plt.imshow(np.random.randn(100, 100))
plt.title("100x100 matrix")
# Out:
# Text(0.5, 1.0, '100x100 matrix')

# %%
x = np.arange(0, 10, 0.1)
y = np.exp(x)
plt.plot(x, y)
plt.title("exponential function: $ y = e^x $")
plt.ylim(0, 3000)
# yを0-5000の範囲に限定
# タイトルの表示にLaTeXの数式も入れています
# Out:
# (0, 3000)

# %%
xmin, xmax = -np.pi, np.pi
x = np.arange(xmin, xmax, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.hlines([-1, 1], xmin, xmax,
           linestyles="dashed")
# y=-1, 1に破線を描画
plt.title(r"$\sin(x)$ and $\cos(x)$")
plt.xlim(xmin, xmax)
plt.ylim(-1.3, 1.3)
# Out:
# (-1.3, 1.3)

# %%
# xとyの値は先ほどと共通

# sinのプロット
plt.subplot(2, 1, 1)
plt.plot(x, y_sin)
plt.title(r"$\sin x$")
plt.xlim(xmin, xmax)
plt.ylim(-1.3, 1.3)

# cosのプロット
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title(r"$\cos x$")
plt.xlim(xmin, xmax)
plt.ylim(-1.3, 1.3)

plt.tight_layout()
# タイトルの被りを防ぐ

# %%
plt.plot([1, 2, 3, 4])
plt.xlabel('簡単なグラフ')
plt.show()

# %%
x = [1,2,3,4]
y = [5,6,7,8]
plt.plot(x, y, 'o-', label="my data")
# plot ... w lp title "my data"
plt.xlabel("X")         
# set xlabel "X"
plt.ylabel("Y")         
# set ylabel "Y"
plt.legend(loc='best')  
# set key

# %%
x = [1,2,3,4]
y1 = [5,6,7,8]
y2 = [4,2,8,6]

plt.plot(x, y1, 'o-', label='y1')  # plot ....
plt.plot(x, y2, 'o-', label='y2')  # replot ...
plt.legend(loc='best')             # set key

# %%
x = np.arange( -3.0, 3.0, 0.01 )
y = np.exp(-x) * np.cos(x)*np.cos(x)
plt.plot(x, y, '-')
plt.yscale('log')

# %%
x = [1,2,3,4]
y = [5,6,7,8]
plt.plot(x, y, 'o-', label="my data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(loc='best')
plt.savefig('Introduction_to_Matplotlib.png')

# %%
len(mpl.style.available)
print(dir(mpl.style.available))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
print(dir(mpl.style))
mpl.style.use
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'available', 'context', 'core', 'library', 'reload_library', 'use']
# <function matplotlib.style.core.use(style)>
