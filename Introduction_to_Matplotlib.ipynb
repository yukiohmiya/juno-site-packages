# %% [markdown]
# # Introduction to Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import japanize_matplotlib
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.arange(0, 2*np.pi, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
x = np.random.randn(30)
y = np.sin(x) + np.random.randn(30)
plt.plot(x, y, "o")
# "o"は小さい円(circle marker)

# %%
plt.plot(x, y, "ro")

# %% [markdown]
# ```
# ?plt.plot
# ```

# %%
plt.hist(np.random.randn(1000))
# Out:
# (array([  6.,  22.,  78., 164., 252., 232., 149.,  78.,  16.,   3.]),
#  array([-3.16399462, -2.51706584, -1.87013706, -1.22320828, -0.5762795 ,
#          0.07064928,  0.71757806,  1.36450684,  2.01143562,  2.6583644 ,
#          3.30529318]),
#  <a list of 10 Patch objects>)

# %%
plt.imshow(np.random.randn(100, 100))
plt.title("100x100 matrix")
# Out:
# Text(0.5, 1.0, '100x100 matrix')

# %%
x = np.arange(0, 10, 0.1)
y = np.exp(x)
plt.plot(x, y)
plt.title("exponential function: $ y = e^x $")
plt.ylim(0, 3000)
# yを0-5000の範囲に限定
# タイトルの表示にLaTeXの数式も入れています
# Out:
# (0, 3000)

# %%
xmin, xmax = -np.pi, np.pi
x = np.arange(xmin, xmax, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.hlines([-1, 1], xmin, xmax,
           linestyles="dashed")
# y=-1, 1に破線を描画
plt.title(r"$\sin(x)$ and $\cos(x)$")
plt.xlim(xmin, xmax)
plt.ylim(-1.3, 1.3)
# Out:
# (-1.3, 1.3)

# %%
# xとyの値は先ほどと共通

# sinのプロット
plt.subplot(2, 1, 1)
plt.plot(x, y_sin)
plt.title(r"$\sin x$")
plt.xlim(xmin, xmax)
plt.ylim(-1.3, 1.3)

# cosのプロット
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title(r"$\cos x$")
plt.xlim(xmin, xmax)
plt.ylim(-1.3, 1.3)

plt.tight_layout()
# タイトルの被りを防ぐ

# %%
plt.plot([1, 2, 3, 4])
plt.xlabel('簡単なグラフ')
# Out:
# Text(0.5, 0, '簡単なグラフ')

# %%
x = [1,2,3,4]
y = [5,6,7,8]
plt.plot(x, y, 'o-', label="my data")
# plot ... w lp title "my data"
plt.xlabel("X")         
# set xlabel "X"
plt.ylabel("Y")         
# set ylabel "Y"
plt.legend(loc='best')  
# set key

# %%
x = [1,2,3,4]
y1 = [5,6,7,8]
y2 = [4,2,8,6]

plt.plot(x, y1, 'o-', label='y1')  # plot ....
plt.plot(x, y2, 'o-', label='y2')  # replot ...
plt.legend(loc='best')             # set key

# %%
x = np.arange( -3.0, 3.0, 0.01 )
y = np.exp(-x) * np.cos(x)*np.cos(x)
plt.plot(x, y, '-')
plt.yscale('log')

# %%
x = [1,2,3,4]
y = [5,6,7,8]
plt.plot(x, y, 'o-', label="my data")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(loc='best')
plt.savefig('Introduction_to_Matplotlib.png')

# %%
plt.scatter(np.random.rand(20),
            np.random.rand(20).cumsum(),
            c=range(20))
plt.colorbar()

# %%
z = np.random.randint(1000, size=20)
plt.scatter(np.random.rand(20),
            np.random.rand(20).cumsum(),
            c=z,
            cmap='Paired')
plt.colorbar()

# %%
plt.bar(range(1, 5), [x**2 for x in range(1,5)])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x=range(4),
        width=-0.5,
        height=[2*x for x in range(1,5)],
        align='edge')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x=range(4),
        width=-0.4,
        height=[x**2 for x in range(1,5)],
        align='edge')
plt.bar(x=range(4),
        width=0.4,
        height=[x*3 for x in range(1,5)],
        align='edge')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x=range(4),
        width=0.4,
        height=[x**2+x*3 for x in range(1,5)])
plt.bar(x=range(4),
        width=0.4,
        height=[x*3 for x in range(1,5)],
        tick_label=['A', 'B', 'C', 'D'])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(y=range(4), width=[x*2 for x in range(1,5)], height=0.6)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.hist([np.random.rand(100), np.random.rand(50)], bins=10)
# Out:
# ([array([ 9., 13.,  8., 13., 13., 14., 10.,  7.,  6.,  7.]),
#   array([8., 5., 6., 6., 4., 5., 2., 6., 6., 2.])],
#  array([0.00143086, 0.10126085, 0.20109084, 0.30092082, 0.40075081,
#         0.50058079, 0.60041078, 0.70024077, 0.80007075, 0.89990074,
#         0.99973072]),
#  <a list of 2 Lists of Patches objects>)

# %%
data = [10, 15, 45, 30, 4]
label = ['A', 'B', 'C', 'D', 'E']
plt.pie(data, labels=label)
# Out:
# ([<matplotlib.patches.Wedge at 0x115a0a2b0>,
# ...
#  [Text(1.050192951391727, 0.3272533649133864, 'A'),
#   Text(0.5403800652918463, 0.9581176258869158, 'B'),
#   Text(-1.059597892852859, 0.29538501224974323, 'C'),
#   Text(0.4514541546289895, -1.00308979970301, 'D'),
#   Text(1.0919797702215333, -0.13259027651727634, 'E')])

# %%
plt.pie(data, counterclock=False, startangle=90)
plt.axis('equal')
# Out:
# (-1.1049305054325265, 1.112790473530017, -1.1259222523414743, 1.10123439593246)

# %%
plt.pie(data, counterclock=False, startangle=90,
        autopct=lambda f: '{:.1f}%'.format(f) if f > 5 else '')
plt.legend(label)
plt.axis('equal')
# Out:
# (-1.1049305054325265, 1.112790473530017, -1.1259222523414743, 1.10123439593246)

# %%
explode = [0, 0.2, 0, 0, 0]
plt.pie(data,
        explode=explode,
        autopct=lambda f: '{:.1f}%'.format(f) if f>5 else '',
        counterclock=False,
        startangle=90,
        wedgeprops={'linewidth': 2, 'edgecolor': 'white'},
        textprops={'color': 'white', 'weight': 'bold'})
plt.axis('equal')
# Out:
# (-1.112950194665586, 1.2812039474242656, -1.1259222523414743, 1.10123439593246)

# %%
def pct_abs(pct, raw_data):
    absolute = int(np.sum(raw_data)*(pct/100.))
    return '{:d}\n({:.0f}%)'.format(absolute, pct) if pct > 5 else ''

plt.pie(data,
        counterclock=False,
        startangle=90,
        autopct=lambda p: pct_abs(p, data),
        pctdistance=0.75,
        textprops={'color': 'white', 'weight':'bold'})
plt.pie([100], colors='white', radius=0.5)
plt.axis('equal')
# Out:
# (-1.1049305054325265, 1.112790473530017, -1.1259222523414743, 1.10123439593246)

# %%
plt.boxplot([np.random.rand(50),
             np.random.randn(50)],
            labels=['uniform', 'normal'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x114919908>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x114926048>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1149197b8>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1149266d8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x114926a20>,
# ...
#  'means': []}

# %%
plt.violinplot([np.random.rand(50),
                np.random.randn(50)],
               showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x115d22898>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x115d22860>,
#  'cmins': <matplotlib.collections.LineCollection at 0x115d22fd0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x114d6d2e8>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x114d6d588>}
